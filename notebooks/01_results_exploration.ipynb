# %% [markdown]
# # MSDP results exploration
# Run the scripted pipeline first; this notebook is supplementary only.

# %%
import pandas as pd
pred = pd.read_csv('../artifacts/predictions/test_predictions.csv')
pred.tail()
